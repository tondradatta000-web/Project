# %% [markdown]
# <a href="https://colab.research.google.com/github/code10-td/Web-Site---Fytverse/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    classification_report
)

# %%
data = pd.read_csv("/content/heart.csv.csv")

print("\nFirst 5 Rows")
print(data.head())

print("\nDataset Shape:", data.shape)

print("\nDataset Information")
print(data.info())

print("\nMissing Values")
print(data.isnull().sum())

print(data)
# Out:
# First 5 Rows
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
#
# Dataset Shape: (1025, 14)
#
# Dataset Information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
# ...

# %%
# ==============================
# Step 2: Target Distribution
# ==============================

plt.figure(figsize=(6,4))
data["target"].value_counts().plot(kind="bar")
plt.title("Heart Disease Distribution")
plt.xlabel("Target")
plt.ylabel("Number of Patients")
plt.xticks([0,1],["No Disease","Disease"],rotation=0)
plt.show()

# %%
# ==============================
# Step 3: Split Features
# ==============================

X = data.drop("target", axis=1)
y = data["target"]

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
# ==============================
# Step 4: Train Model
# ==============================

model = RandomForestClassifier(
    n_estimators=200,
    random_state=42
)

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
# ==============================
# Step 5: Prediction
# ==============================

# ==========================================
# HEART DISEASE PREDICTION REPORT
# ==========================================

prediction = model.predict(new_patient)
prob = model.predict_proba(new_patient)

risk = prob[0][1] * 100

print("\n")
print("="*60)
print("        HEART DISEASE PREDICTION REPORT")
print("="*60)

if prediction[0] == 1:

    print("Prediction      : HEART DISEASE DETECTED")
    print("Patient Status  : POSITIVE")

else:

    print("Prediction      : NO HEART DISEASE")
    print("Patient Status  : NEGATIVE")

print("-"*60)

print("Probability")

print(f"No Disease : {prob[0][0]*100:.2f}%")
print(f"Disease    : {prob[0][1]*100:.2f}%")

print("-"*60)

# ===========================
# Risk Level
# ===========================

if risk < 30:

    print("Risk Level : LOW")

elif risk < 70:

    print("Risk Level : MEDIUM")

else:

    print("Risk Level : HIGH")

print("-"*60)

print("Recommendation")

if prediction[0] == 1:

    print("• Consult a Cardiologist")
    print("• Monitor Blood Pressure")
    print("• Reduce Cholesterol")
    print("• Exercise Regularly")
    print("• Avoid Smoking")
    print("• Reduce Salt Intake")
    print("• Eat More Vegetables")
    print("• Sleep 7-8 Hours")

else:

    print("• Maintain Healthy Lifestyle")
    print("• Continue Regular Exercise")
    print("• Eat Healthy Food")
    print("• Routine Health Checkup")

print("="*60)
# Out:
# ...
#         HEART DISEASE PREDICTION REPORT
# ...
# Prediction      : HEART DISEASE DETECTED
# Patient Status  : POSITIVE
# ------------------------------------------------------------
# Probability
# No Disease : 8.00%
# Disease    : 92.00%
# ------------------------------------------------------------
# Risk Level : HIGH
# ------------------------------------------------------------
# Recommendation
# • Consult a Cardiologist
# • Monitor Blood Pressure
# • Reduce Cholesterol
# • Exercise Regularly
# • Avoid Smoking
# • Reduce Salt Intake
# • Eat More Vegetables
# • Sleep 7-8 Hours
# ...

# %%
# ==============================
# Step 6: Confusion Matrix
# ==============================

cm = confusion_matrix(y_test,y_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=["No Disease","Disease"]
)

disp.plot()
plt.title("Confusion Matrix")
plt.show()

# %%
# ==============================
# Step 7: Feature Importance
# ==============================

importance = pd.DataFrame({

    "Feature":X.columns,
    "Importance":model.feature_importances_

})

importance = importance.sort_values(
    by="Importance",
    ascending=True
)

plt.figure(figsize=(8,6))

plt.barh(
    importance["Feature"],
    importance["Importance"]
)

plt.title("Feature Importance")

plt.xlabel("Importance Score")

plt.grid()

plt.show()

# %%
# ==============================
# Step 8: Predict New Patient
# ==============================

# Replace these with actual values from your dataset
new_patient = pd.DataFrame([[
    52,     # age
    1,      # sex
    2,      # cp
    130,    # trestbps
    220,    # chol
    0,      # fbs
    1,      # restecg
    150,    # thalach
    0,      # exang
    1.5,    # oldpeak
    2,      # slope
    0,      # ca
    2       # thal
]], columns=X.columns)

prediction = model.predict(new_patient)

print("\nPrediction")

if prediction[0] == 1:
    print("Heart Disease Detected")
else:
    print("No Heart Disease")
# Out:
# Prediction
# Heart Disease Detected

# %%
# ==============================
# Step 9: Probability
# ==============================
risk = prob[0][1] * 100

print("\n========== Risk Analysis ==========")

if risk < 30:
    print("Risk Level : LOW")
elif risk < 70:
    print("Risk Level : MEDIUM")
else:
    print("Risk Level : HIGH")

print(f"Heart Disease Probability : {risk:.2f}%")
# Out:
# ========== Risk Analysis ==========
# Risk Level : HIGH
# Heart Disease Probability : 92.00%

# %%
plt.figure(figsize=(6,5))

labels = ["No Disease","Disease"]

values = [
    prob[0][0]*100,
    prob[0][1]*100
]

bars = plt.bar(labels, values)

plt.title("Heart Disease Prediction Probability")
plt.ylabel("Probability (%)")

for i,v in enumerate(values):

    plt.text(i,v+1,f"{v:.2f}%",ha="center",fontsize=11)

plt.ylim(0,100)

plt.grid(axis="y")

plt.show()
